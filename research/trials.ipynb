# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2 = ConfigBox(d2)
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int,y:int):
    return x*y

# %%
get_product(2,3)
# Out:
# 6

# %%
get_product(2,"3")
# Out:
# '33'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y
get_product(x = 2, y = 3)
# Out:
# 6

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y
get_product(x = 2, y = "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[9], line 5
#       2 @ensure_annotations
#       3 def get_product(x:int, y:int):
#       4     return x*y
# ----> 5 get_product(x = 2, y = "3")
#
# File e:\ml_end to end project\END-to-END-Chest-Cancer\cancer\lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000018DA24E0700> does not match annotation type <class 'int'>
